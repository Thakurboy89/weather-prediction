# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("/content/seattle-weather.csv")

# %%
print(df.head())
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
# Preprocessing
# Assume columns: 'date', 'temperature', 'precipitation', etc.
df['date'] = pd.to_datetime(df['date'])
df['day_of_year'] = df['date'].dt.dayofyear
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
features = df[['day_of_year', 'month', 'precipitation']]  # Add more features as necessary
target = df['weather']

# %%
X_train
# Out:
#       day_of_year  month  precipitation weather
# 1066          336     12            0.0     fog
# 638           273      9           18.5    rain
# 799            69      3           18.8    rain
# 380            15      1            0.0     sun
# 303           304     10           34.5    rain
# ...           ...    ...            ...     ...
# 1130           35      2            8.4    rain
# 1294          199      7            0.0     sun
# 860           130      5            0.5    rain
# 1459          364     12            0.0     sun
# 1126           31      1            0.0     fog
#
# [1168 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#       day_of_year  month  precipitation
# 1066          336     12            0.0
# 638           273      9           18.5
# 799            69      3           18.8
# 380            15      1            0.0
# 303           304     10           34.5
# ...           ...    ...            ...
# 1130           35      2            8.4
# 1294          199      7            0.0
# 860           130      5            0.5
# 1459          364     12            0.0
# 1126           31      1            0.0
#
# [1168 rows x 3 columns]

# %%
y_train
# Out:
# 1066     fog
# 638     rain
# 799     rain
# 380      sun
# 303     rain
#         ...
# 1130    rain
# 1294     sun
# 860     rain
# 1459     sun
# 1126     fog
# Name: weather, Length: 1168, dtype: object

# %%
# Assuming 'features' and 'target' are your data
# ... (your code for loading and preparing data)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Initialize LabelEncoder
encoder = LabelEncoder()

# Fit the encoder on the training target data and transform both training and testing target data
y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test) # Encode y_test using the same encoder

# Initialize and train the model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Calculate and print the Mean Squared Error
print(f'Mean Squared Error: {mean_squared_error(y_test, y_pred)}')
# Out:
# Mean Squared Error: 1.385290818927372

# %%
df.weather.unique()
# Out:
# array(['drizzle', 'rain', 'sun', 'snow', 'fog'], dtype=object)

# %%
weather = df.weather.unique()

# %%
import random

def predict_next_weather(current_weather, transition_matrix):
    # Get the next weather states and their probabilities
    next_weather_states = list(transition_matrix[current_weather].keys())
    probabilities = list(transition_matrix[current_weather].values())

    # Randomly choose the next weather condition based on the probabilities
    next_weather = random.choices(next_weather_states, probabilities)[0]
    return next_weather

# Example usage
current_weather = 'Fog'  # Assume today's weather is Fog

# Define the transition matrix - Replace with your actual probabilities
transition_matrix = {
    'Fog': {'Fog': 0.6, 'Sun': 0.2, 'Rain': 0.2},
    'Sun': {'Fog': 0.1, 'Sun': 0.7, 'Rain': 0.2},
    'Rain': {'Fog': 0.3, 'Sun': 0.2, 'Rain': 0.5},
    # ... add other weather conditions and their transitions
}

next_weather = predict_next_weather(current_weather, transition_matrix)
print(f"Tomorrow's predicted weather: {next_weather}")
# Out:
# Tomorrow's predicted weather: Rain

# %%
import random

def predict_next_weather(current_weather, transition_matrix):
    # Get the next weather states and their probabilities
    next_weather_states = list(transition_matrix[current_weather].keys())
    probabilities = list(transition_matrix[current_weather].values())

    # Randomly choose the next weather condition based on the probabilities
    next_weather = random.choices(next_weather_states, probabilities)[0]
    return next_weather

def predict_weather_for_days(current_weather, transition_matrix, days=7):
    forecast = []
    for _ in range(days):
        next_weather = predict_next_weather(current_weather, transition_matrix)
        forecast.append(next_weather)
        current_weather = next_weather  # Update current_weather for the next day
    return forecast

# Define the transition matrix - Replace with your actual probabilities
transition_matrix = {
    'Fog': {'Fog': 0.6, 'Sun': 0.2, 'Rain': 0.2},
    'Sun': {'Fog': 0.1, 'Sun': 0.7, 'Rain': 0.2},
    'Rain': {'Fog': 0.3, 'Sun': 0.2, 'Rain': 0.5},
    # ... add other weather conditions and their transitions
}

# Example usage for a 7-day forecast
current_weather = 'Fog'
seven_day_forecast = predict_weather_for_days(current_weather, transition_matrix, days=7)
print("7-Day Weather Forecast:", seven_day_forecast)
# Out:
# 7-Day Weather Forecast: ['Fog', 'Rain', 'Sun', 'Fog', 'Fog', 'Rain', 'Sun']

# %%
for i, prediction in enumerate(predictions):
    print(f"Day {i + 1}: weather = {prediction}°C")  # Adjust based on your target variable
# Out:
# Day 1: weather = [2.63814286]°C
# Day 2: weather = [2.01]°C
# Day 3: weather = [2.]°C
# Day 4: weather = [2.]°C
# Day 5: weather = [2.]°C
# Day 6: weather = [2.]°C
# Day 7: weather = [2.]°C

# %%
df.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather  day_of_year  \
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle            1
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain            2
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain            3
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain            4
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain            5
#
#    month  year
# 0      1  2012
# 1      1  2012
# 2      1  2012
# 3      1  2012
# 4      1  2012
